# %%
import numpy as np
import pandas as pd
import os
from os.path import isfile

import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop
from keras import regularizers

import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Training and Validation Data Sets Load

# %% [markdown]
# #### Define global paths

# %%
DATA_DIR = '/Users/james/Documents/Data/genre classification/' 
AUDIO_DIR = DATA_DIR + 'Audio' 
NPZ_DIR = DATA_DIR + 'npz'

# %%
# folder to save model results
if not os.path.exists('./models/crnn_all_genres'):
    os.makedirs('./models/crnn_all_genres')

# %% [markdown]
# #### load

# %%
# load the meta data from data transformer step
meta_data_df = pd.read_pickle(DATA_DIR + '/meta_data.pkl')

# %%
npzfile = np.load(NPZ_DIR + '/shuffled_train_all_genres.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (2024, 640, 128) (2024, 29)

# %%
npzfile = np.load(NPZ_DIR + '/shuffled_valid_all_genres.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (579, 640, 128) (579, 29)

# %% [markdown]
# #### genre look-up (based off of genre_target variable in data_transformer

# %%
genre_list = meta_data_df['genre'].unique()
genre_dict = {genre_list[i] : i for i in range(0, len(genre_list))}

reverse_genre_dict = {j:i for i, j in genre_dict.items()}
print(reverse_genre_dict)
# Out:
# {0: 'Afro House', 1: 'Big Room', 2: 'Breaks', 3: 'Dance', 4: 'Deep House', 5: 'Drum & Bass', 6: 'Dubstep', 7: 'Electro House', 8: 'Electronica', 9: 'Funk-Soul-Disco', 10: 'Funk-Groove-Jackin-House', 11: 'Future House', 12: 'Garage-Bassline-Grime', 13: 'Glitch', 14: 'Hard Dance', 15: 'Hard Techno', 16: 'Hip-Hop', 17: 'House', 18: 'Indie Dance', 19: 'Leftfield Bass', 20: 'Leftfield House and Techno', 21: 'Minimal Deep Tech', 22: 'Progressive House', 23: 'Psy-Trance', 24: 'Reggae and Dancehall', 25: 'Tech House', 26: 'Techno', 27: 'Trance', 28: 'Trap'}

# %% [markdown]
# #### Spectrogram Checks

# %%
example_track_num = 1000
spectogram = X_train[example_track_num]
genre = np.argmax(y_train[example_track_num])
print(genre)
print(reverse_genre_dict[genre])
# Out:
# 18
# Indie Dance

# %%
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram for genre = ' + reverse_genre_dict[genre])
plt.tight_layout()

# %% [markdown]
# ### CNN-RNN Serial Model

# %%
batch_size = 32
num_classes = y_train.shape[1]
print(f"number of genres: {num_classes}")
n_features = X_train.shape[2]
print(f"number of features/frequency_bands: {n_features}")
n_time = X_train.shape[1]
print(f"number of time steps: {n_time}")
# Out:
# number of genres: 29
# number of features/frequency_bands: 128
# number of time steps: 640

# %%
N_LAYERS = 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 32
LSTM_COUNT = 96
EPOCH_COUNT = 70
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.4)(layer)
    
    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    ## Softmax Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    opt = Adam(lr=0.001)
    model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    #y_train = np_utils.to_categorical(y_train, num_classes) 
    #y_val   = np_utils.to_categorical(y_val, num_classes) 
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/crnn_all_genres/weights.best.h5', monitor='val_acc', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_acc', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
# run
model, history = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0718 13:43:04.575608 4575139264 deprecation_wrapper.py:119] From /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0718 13:43:04.620403 4575139264 deprecation_wrapper.py:119] From /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0718 13:43:04.648274 4575139264 deprecation_wrapper.py:119] From /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0718 13:43:04.715465 4575139264 deprecation_wrapper.py:119] From /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0718 13:43:04.729324 4575139264 deprecation_wrapper.py:119] From /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0718 13:43:04.734917 4575139264 deprecation.py:506] From /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Building model...
# W0718 13:43:05.184090 4575139264 deprecation_wrapper.py:119] From /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0718 13:43:05.190215 4575139264 deprecation_wrapper.py:119] From /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0718 13:43:05.318603 4575139264 deprecation.py:323] From /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, None, 128)         0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_1 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_2 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_3 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                1885
# _________________________________________________________________
# output_realtime (Activation) (None, 29)                0
# =================================================================
# Total params: 134,885
# Trainable params: 134,549
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# Train on 2024 samples, validate on 579 samples
# Epoch 1/70
# 2024/2024 [==============================] - 12s 6ms/step - loss: 3.6721 - acc: 0.0435 - val_loss: 3.6150 - val_acc: 0.0415
#
# Epoch 00001: val_acc improved from -inf to 0.04145, saving model to ./models/crnn_all_genres/weights.best.h5
# Epoch 2/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 3.5778 - acc: 0.0578 - val_loss: 3.6057 - val_acc: 0.0656
#
# Epoch 00002: val_acc improved from 0.04145 to 0.06563, saving model to ./models/crnn_all_genres/weights.best.h5
# Epoch 3/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 3.5329 - acc: 0.0637 - val_loss: 3.7810 - val_acc: 0.0345
#
# Epoch 00003: val_acc did not improve from 0.06563
# Epoch 4/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 3.4828 - acc: 0.0810 - val_loss: 3.8410 - val_acc: 0.0570
#
# Epoch 00004: val_acc did not improve from 0.06563
# Epoch 5/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 3.4323 - acc: 0.0904 - val_loss: 3.6313 - val_acc: 0.0570
#
# Epoch 00005: val_acc did not improve from 0.06563
# Epoch 6/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 3.3758 - acc: 0.1003 - val_loss: 3.6056 - val_acc: 0.0587
#
# Epoch 00006: val_acc did not improve from 0.06563
# Epoch 7/70
# 2024/2024 [==============================] - 13s 6ms/step - loss: 3.3416 - acc: 0.1023 - val_loss: 3.5953 - val_acc: 0.0604
#
# Epoch 00007: val_acc did not improve from 0.06563
# Epoch 8/70
# 2024/2024 [==============================] - 16s 8ms/step - loss: 3.3218 - acc: 0.0968 - val_loss: 3.7865 - val_acc: 0.0518
#
# Epoch 00008: val_acc did not improve from 0.06563
# Epoch 9/70
# 2024/2024 [==============================] - 17s 8ms/step - loss: 3.2934 - acc: 0.1052 - val_loss: 3.6460 - val_acc: 0.0898
#
# Epoch 00009: val_acc improved from 0.06563 to 0.08981, saving model to ./models/crnn_all_genres/weights.best.h5
# Epoch 10/70
# 2024/2024 [==============================] - 13s 7ms/step - loss: 3.2642 - acc: 0.1215 - val_loss: 3.8109 - val_acc: 0.0466
#
# Epoch 00010: val_acc did not improve from 0.08981
# Epoch 11/70
# 2024/2024 [==============================] - 12s 6ms/step - loss: 3.2224 - acc: 0.1285 - val_loss: 3.8004 - val_acc: 0.0518
#
# Epoch 00011: val_acc did not improve from 0.08981
# Epoch 12/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 3.1984 - acc: 0.1265 - val_loss: 4.0924 - val_acc: 0.0328
#
# Epoch 00012: val_acc did not improve from 0.08981
# Epoch 13/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 3.1908 - acc: 0.1319 - val_loss: 3.6526 - val_acc: 0.0708
#
# Epoch 00013: val_acc did not improve from 0.08981
# Epoch 14/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 3.1654 - acc: 0.1408 - val_loss: 3.9203 - val_acc: 0.0518
#
# Epoch 00014: val_acc did not improve from 0.08981
# Epoch 15/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 3.1243 - acc: 0.1497 - val_loss: 3.7115 - val_acc: 0.0553
#
# Epoch 00015: val_acc did not improve from 0.08981
# Epoch 16/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 3.0914 - acc: 0.1551 - val_loss: 3.7096 - val_acc: 0.0587
#
# Epoch 00016: val_acc did not improve from 0.08981
# Epoch 17/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 3.1336 - acc: 0.1453 - val_loss: 3.6042 - val_acc: 0.0794
#
# Epoch 00017: val_acc did not improve from 0.08981
# Epoch 18/70
# 2024/2024 [==============================] - 12s 6ms/step - loss: 3.1590 - acc: 0.1403 - val_loss: 3.8499 - val_acc: 0.0518
#
# Epoch 00018: val_acc did not improve from 0.08981
# Epoch 19/70
# 2024/2024 [==============================] - 11s 6ms/step - loss: 3.0745 - acc: 0.1527 - val_loss: 3.6343 - val_acc: 0.0708
#
# Epoch 00019: val_acc did not improve from 0.08981
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.9811 - acc: 0.1744 - val_loss: 3.5512 - val_acc: 0.0898
#
# Epoch 00020: val_acc did not improve from 0.08981
# Epoch 21/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.9380 - acc: 0.1798 - val_loss: 3.5005 - val_acc: 0.1140
#
# Epoch 00021: val_acc improved from 0.08981 to 0.11399, saving model to ./models/crnn_all_genres/weights.best.h5
# Epoch 22/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.9358 - acc: 0.1754 - val_loss: 3.6662 - val_acc: 0.0950
#
# Epoch 00022: val_acc did not improve from 0.11399
# Epoch 23/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.8995 - acc: 0.1897 - val_loss: 3.4844 - val_acc: 0.1174
#
# Epoch 00023: val_acc improved from 0.11399 to 0.11744, saving model to ./models/crnn_all_genres/weights.best.h5
# Epoch 24/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.8629 - acc: 0.1957 - val_loss: 3.6889 - val_acc: 0.0967
#
# Epoch 00024: val_acc did not improve from 0.11744
# Epoch 25/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.8340 - acc: 0.2041 - val_loss: 3.8276 - val_acc: 0.0915
#
# Epoch 00025: val_acc did not improve from 0.11744
# Epoch 26/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.8341 - acc: 0.2154 - val_loss: 3.8315 - val_acc: 0.0933
#
# Epoch 00026: val_acc did not improve from 0.11744
# Epoch 27/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.7846 - acc: 0.2144 - val_loss: 3.6557 - val_acc: 0.1088
#
# Epoch 00027: val_acc did not improve from 0.11744
# Epoch 28/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.7676 - acc: 0.2258 - val_loss: 3.9264 - val_acc: 0.0725
#
# Epoch 00028: val_acc did not improve from 0.11744
# Epoch 29/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.7597 - acc: 0.2302 - val_loss: 3.7889 - val_acc: 0.1209
#
# Epoch 00029: val_acc improved from 0.11744 to 0.12090, saving model to ./models/crnn_all_genres/weights.best.h5
# Epoch 30/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.7314 - acc: 0.2347 - val_loss: 3.7704 - val_acc: 0.1192
#
# Epoch 00030: val_acc did not improve from 0.12090
# Epoch 31/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.7165 - acc: 0.2307 - val_loss: 3.6753 - val_acc: 0.1105
#
# Epoch 00031: val_acc did not improve from 0.12090
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 32/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.6869 - acc: 0.2540 - val_loss: 3.6064 - val_acc: 0.1140
#
# Epoch 00032: val_acc did not improve from 0.12090
# Epoch 33/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.6425 - acc: 0.2564 - val_loss: 3.4401 - val_acc: 0.1744
#
# Epoch 00033: val_acc improved from 0.12090 to 0.17444, saving model to ./models/crnn_all_genres/weights.best.h5
# Epoch 34/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.6068 - acc: 0.2638 - val_loss: 3.6417 - val_acc: 0.1468
#
# Epoch 00034: val_acc did not improve from 0.17444
# Epoch 35/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.5675 - acc: 0.2806 - val_loss: 3.5008 - val_acc: 0.1744
#
# Epoch 00035: val_acc did not improve from 0.17444
# Epoch 36/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.5788 - acc: 0.2811 - val_loss: 3.9363 - val_acc: 0.1036
#
# Epoch 00036: val_acc did not improve from 0.17444
# Epoch 37/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.5533 - acc: 0.2747 - val_loss: 3.6967 - val_acc: 0.1485
#
# Epoch 00037: val_acc did not improve from 0.17444
# Epoch 38/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.5378 - acc: 0.2727 - val_loss: 3.8074 - val_acc: 0.0829
#
# Epoch 00038: val_acc did not improve from 0.17444
# Epoch 39/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.5352 - acc: 0.2698 - val_loss: 4.3024 - val_acc: 0.0466
#
# Epoch 00039: val_acc did not improve from 0.17444
# Epoch 40/70
# 2024/2024 [==============================] - 11s 6ms/step - loss: 2.5130 - acc: 0.2851 - val_loss: 4.0087 - val_acc: 0.1261
#
# Epoch 00040: val_acc did not improve from 0.17444
# Epoch 41/70
# 2024/2024 [==============================] - 12s 6ms/step - loss: 2.4812 - acc: 0.2935 - val_loss: 3.6733 - val_acc: 0.1157
#
# Epoch 00041: val_acc did not improve from 0.17444
# Epoch 42/70
# 2024/2024 [==============================] - 11s 6ms/step - loss: 2.5093 - acc: 0.2792 - val_loss: 3.7059 - val_acc: 0.1226
#
# Epoch 00042: val_acc did not improve from 0.17444
# Epoch 43/70
# 2024/2024 [==============================] - 13s 6ms/step - loss: 2.4959 - acc: 0.2915 - val_loss: 3.9342 - val_acc: 0.0777
#
# Epoch 00043: val_acc did not improve from 0.17444
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 44/70
# 2024/2024 [==============================] - 12s 6ms/step - loss: 2.4378 - acc: 0.3043 - val_loss: 3.6117 - val_acc: 0.1623
#
# Epoch 00044: val_acc did not improve from 0.17444
# Epoch 45/70
# 2024/2024 [==============================] - 12s 6ms/step - loss: 2.4195 - acc: 0.3039 - val_loss: 3.7655 - val_acc: 0.1192
#
# Epoch 00045: val_acc did not improve from 0.17444
# Epoch 46/70
# 2024/2024 [==============================] - 11s 6ms/step - loss: 2.4130 - acc: 0.3034 - val_loss: 3.5965 - val_acc: 0.1883
#
# Epoch 00046: val_acc improved from 0.17444 to 0.18826, saving model to ./models/crnn_all_genres/weights.best.h5
# Epoch 47/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.4325 - acc: 0.3142 - val_loss: 3.9189 - val_acc: 0.1174
#
# Epoch 00047: val_acc did not improve from 0.18826
# Epoch 48/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3904 - acc: 0.3236 - val_loss: 4.1073 - val_acc: 0.0674
#
# Epoch 00048: val_acc did not improve from 0.18826
# Epoch 49/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.4083 - acc: 0.3039 - val_loss: 4.1895 - val_acc: 0.1382
#
# Epoch 00049: val_acc did not improve from 0.18826
# Epoch 50/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3842 - acc: 0.3291 - val_loss: 3.6899 - val_acc: 0.1606
#
# Epoch 00050: val_acc did not improve from 0.18826
# Epoch 51/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3799 - acc: 0.3281 - val_loss: 3.7411 - val_acc: 0.1451
#
# Epoch 00051: val_acc did not improve from 0.18826
# Epoch 52/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3787 - acc: 0.3335 - val_loss: 3.6892 - val_acc: 0.1485
#
# Epoch 00052: val_acc did not improve from 0.18826
# Epoch 53/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3518 - acc: 0.3345 - val_loss: 3.9143 - val_acc: 0.1123
#
# Epoch 00053: val_acc did not improve from 0.18826
# Epoch 54/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3410 - acc: 0.3291 - val_loss: 3.8943 - val_acc: 0.1244
#
# Epoch 00054: val_acc did not improve from 0.18826
# Epoch 55/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3570 - acc: 0.3370 - val_loss: 3.7596 - val_acc: 0.1589
#
# Epoch 00055: val_acc did not improve from 0.18826
# Epoch 56/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3186 - acc: 0.3251 - val_loss: 3.8415 - val_acc: 0.1606
#
# Epoch 00056: val_acc did not improve from 0.18826
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 57/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3182 - acc: 0.3355 - val_loss: 3.8819 - val_acc: 0.1209
#
# Epoch 00057: val_acc did not improve from 0.18826
# Epoch 58/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3097 - acc: 0.3439 - val_loss: 3.6849 - val_acc: 0.1641
#
# Epoch 00058: val_acc did not improve from 0.18826
# Epoch 59/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3188 - acc: 0.3458 - val_loss: 3.6525 - val_acc: 0.1831
#
# Epoch 00059: val_acc did not improve from 0.18826
# Epoch 60/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3025 - acc: 0.3330 - val_loss: 3.6421 - val_acc: 0.1675
#
# Epoch 00060: val_acc did not improve from 0.18826
# Epoch 61/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3041 - acc: 0.3241 - val_loss: 3.6694 - val_acc: 0.1606
#
# Epoch 00061: val_acc did not improve from 0.18826
# Epoch 62/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.2913 - acc: 0.3523 - val_loss: 3.6512 - val_acc: 0.1883
#
# Epoch 00062: val_acc improved from 0.18826 to 0.18826, saving model to ./models/crnn_all_genres/weights.best.h5
# Epoch 63/70
# 2024/2024 [==============================] - 11s 5ms/step - loss: 2.2686 - acc: 0.3320 - val_loss: 3.6682 - val_acc: 0.1537
#
# Epoch 00063: val_acc did not improve from 0.18826
# Epoch 64/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.3085 - acc: 0.3414 - val_loss: 3.7288 - val_acc: 0.1813
#
# Epoch 00064: val_acc did not improve from 0.18826
# Epoch 65/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.2781 - acc: 0.3493 - val_loss: 3.6334 - val_acc: 0.1848
#
# Epoch 00065: val_acc did not improve from 0.18826
# Epoch 66/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.2853 - acc: 0.3320 - val_loss: 3.7307 - val_acc: 0.1520
#
# Epoch 00066: val_acc did not improve from 0.18826
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 67/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.2933 - acc: 0.3365 - val_loss: 3.7461 - val_acc: 0.1572
#
# Epoch 00067: val_acc did not improve from 0.18826
# Epoch 68/70
# 2024/2024 [==============================] - 10s 5ms/step - loss: 2.2839 - acc: 0.3429 - val_loss: 3.7418 - val_acc: 0.1675
#
# Epoch 00068: val_acc did not improve from 0.18826
# Epoch 69/70
# 2024/2024 [==============================] - 9s 5ms/step - loss: 2.2769 - acc: 0.3434 - val_loss: 3.6753 - val_acc: 0.1813
#
# Epoch 00069: val_acc did not improve from 0.18826
# Epoch 70/70
# 2024/2024 [==============================] - 9s 5ms/step - loss: 2.2518 - acc: 0.3587 - val_loss: 3.7209 - val_acc: 0.1693
#
# Epoch 00070: val_acc did not improve from 0.18826

# %%
show_summary_stats(history)
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
target_names = reverse_genre_dict.values()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (579,) (579,)
#                             precision    recall  f1-score   support
#
#                 Afro House       0.40      0.54      0.46        26
#                   Big Room       0.21      0.19      0.20        21
#                     Breaks       0.00      0.00      0.00        20
#                      Dance       0.25      0.16      0.19        19
#                 Deep House       0.14      0.04      0.06        25
#                Drum & Bass       0.00      0.00      0.00        19
#                    Dubstep       0.00      0.00      0.00        18
#              Electro House       0.00      0.00      0.00        22
#                Electronica       0.00      0.00      0.00        17
#            Funk-Soul-Disco       0.00      0.00      0.00        22
#   Funk-Groove-Jackin-House       0.11      0.17      0.13        18
#               Future House       0.03      0.10      0.04        10
#      Garage-Bassline-Grime       0.00      0.00      0.00        14
#                     Glitch       0.07      0.04      0.05        24
#                 Hard Dance       0.03      0.05      0.04        19
#                Hard Techno       0.22      0.50      0.31        20
#                    Hip-Hop       0.23      0.17      0.19        18
#                      House       0.29      0.24      0.26        21
#                Indie Dance       0.17      0.06      0.09        17
#             Leftfield Bass       0.30      0.24      0.27        25
# Leftfield House and Techno       0.18      0.16      0.17        19
#          Minimal Deep Tech       0.42      0.22      0.29        23
#          Progressive House       0.22      0.43      0.29        23
#                 Psy-Trance       0.24      0.18      0.21        22
#       Reggae and Dancehall       0.33      0.29      0.31        14
#                 Tech House       0.11      0.17      0.13        12
#                     Techno       0.14      0.11      0.12        19
#                     Trance       0.21      0.24      0.23        29
#                       Trap       0.57      0.35      0.43        23
#
#                   accuracy                           0.17       579
#                  macro avg       0.17      0.16      0.15       579
#               weighted avg       0.18      0.17      0.16       579
# /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.1692573402417962

# %% [markdown]
# ### Test

# %%
from keras.models import load_model

weights_path = 'models/crnn_all_genres/weights.best.h5'
model = load_model(weights_path)

# %%
npzfile = np.load(NPZ_DIR + '/test_array_all_genres.npz')
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# (289, 640, 128) (289, 29)

# %%
# scale
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0 0.003061754925876369

# %%
X_test = np.log(X_test_raw)

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_test, axis = 1)
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
target_names = reverse_genre_dict.values()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (289,) (289,)
#                             precision    recall  f1-score   support
#
#                 Afro House       0.40      0.43      0.41        14
#                   Big Room       0.00      0.00      0.00         9
#                     Breaks       0.00      0.00      0.00         9
#                      Dance       0.00      0.00      0.00        11
#                 Deep House       0.00      0.00      0.00        14
#                Drum & Bass       0.00      0.00      0.00         7
#                    Dubstep       0.12      0.75      0.21         4
#              Electro House       0.00      0.00      0.00         9
#                Electronica       0.45      0.45      0.45        11
#            Funk-Soul-Disco       0.33      0.38      0.35         8
#   Funk-Groove-Jackin-House       0.58      0.58      0.58        12
#               Future House       0.31      0.36      0.33        11
#      Garage-Bassline-Grime       0.71      0.36      0.48        14
#                     Glitch       0.00      0.00      0.00         8
#                 Hard Dance       0.32      0.89      0.47         9
#                Hard Techno       0.41      0.50      0.45        14
#                    Hip-Hop       0.17      0.10      0.12        10
#                      House       0.00      0.00      0.00         7
#                Indie Dance       0.00      0.00      0.00         9
#             Leftfield Bass       0.32      0.70      0.44        10
# Leftfield House and Techno       0.00      0.00      0.00         6
#          Minimal Deep Tech       0.14      0.50      0.22         2
#          Progressive House       0.00      0.00      0.00         6
#                 Psy-Trance       0.00      0.00      0.00        12
#       Reggae and Dancehall       0.00      0.00      0.00        17
#                 Tech House       0.12      0.14      0.13        14
#                     Techno       0.00      0.00      0.00        10
#                     Trance       0.50      0.40      0.44        10
#                       Trap       0.25      0.33      0.29        12
#
#                   accuracy                           0.23       289
#                  macro avg       0.18      0.24      0.19       289
#               weighted avg       0.20      0.23      0.20       289
# /Users/james/Documents/Virtual Environments/deep-audio-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
model.evaluate(X_test, y_test)
# Out:
# 289/289 [==============================] - 1s 3ms/step
# [0.5896933276244926, 0.8442906574394463]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

mat = confusion_matrix(y_true, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=reverse_genre_dict.values(),
            yticklabels=reverse_genre_dict.values())
plt.xlabel('true label')
plt.ylabel('predicted label');
